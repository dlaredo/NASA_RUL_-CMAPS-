# %% [markdown]
# # Initialization
#
# Test notebook for the DataHandlers. Test the CMAPSS DataHandler
#
# First we import the necessary packages and create the global variables.

# %%
import numpy as np
import math
import tensorflow as tf

from data_handler_CMAPS import CMAPSDataHandler
from tunable_model import SequenceTunableModelRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Dropout, Reshape, Conv2D, Flatten, MaxPooling2D, LSTM
from keras.optimizers import Adam, SGD
from keras.callbacks import LearningRateScheduler
from keras import backend as K
from keras import regularizers

import CMAPSAuxFunctions

from numpy.random import seed
from tensorflow import set_random_seed
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Define different types of Keras models

# %%
l2_lambda_regularization = 0.20
l1_lambda_regularization = 0.10

def RULmodel_LSTM(input_shape):
    """Define the RNN model"""
    
    #Create a sequential model
    model = Sequential()
    #model.add(Masking(mask_value=0, imput))
    #model.add(LSTM(input_shape=input_shape, units=100, return_sequences=True, name='lstm1')))
    model.add(LSTM(input_shape=input_shape, units=20, return_sequences=False, name='lstm2'))
    model.add(Dense(10, input_dim=input_shape, activation='relu', kernel_initializer='glorot_normal', 
                    kernel_regularizer=regularizers.l2(l2_lambda_regularization), name='fc1'))
    model.add(Dense(1, activation='linear', name='out'))
    
    return model
    

def RULmodel_SN_5(input_shape):
    #Create a sequential model
    model = Sequential()
    
    #Add the layers for the model
    model.add(Dense(20, input_dim=input_shape, activation='relu', kernel_initializer='glorot_normal', 
                    kernel_regularizer=regularizers.L1L2(l1_lambda_regularization, l2_lambda_regularization), 
                    name='fc1'))
    model.add(Dense(20, input_dim=input_shape, activation='relu', kernel_initializer='glorot_normal', 
                    kernel_regularizer=regularizers.L1L2(l1_lambda_regularization, l2_lambda_regularization), 
                    name='fc2'))
    model.add(Dense(1, activation='linear', 
                    kernel_regularizer=regularizers.L1L2(l1_lambda_regularization, l2_lambda_regularization), name='out'))
    
    return model

def test_model(input_shape):
    #Create a sequential model
    model = Sequential()
    
    #Add the layers for the model
    model.add(Dense(20, input_dim=input_shape, activation='relu', 
                    kernel_initializer=keras.initializers.glorot_normal(seed=0), 
                    kernel_regularizer=regularizers.l2(l2_lambda_regularization), name='fc1'))
    model.add(Dense(1, activation='linear', 
                    kernel_initializer=keras.initializers.glorot_normal(seed=0), 
                    kernel_regularizer=regularizers.l2(l2_lambda_regularization), name='out'))
    
    return model

# %% [markdown]
# # Tensorflow Models

# %%
def create_placeholders(input_shape, output_shape):
    
    X = tf.placeholder(tf.float32, shape=(None,input_shape), name="X")
    y = tf.placeholder(tf.float32, shape=None, name="y")
    
    return X, y


def tf_model(X):
    
    l2_lambda_regularization = 0.2
    
    A1 = tf.layers.dense(X, 20, activation=tf.nn.relu, kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=False), kernel_regularizer=regularizers.l2(l2_lambda_regularization), name="fc1")
    A2 = tf.layers.dense(A1, 20, activation=tf.nn.relu, kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=False), kernel_regularizer=regularizers.l2(l2_lambda_regularization), name="fc2")
    y = tf.layers.dense(A2, 1, activation=None, kernel_initializer=tf.contrib.layers.xavier_initializer(uniform=False), kernel_regularizer=regularizers.l2(l2_lambda_regularization), name="out")
    
    return y

# %%
def print_model_weights(model):

    for layer in model.layers:
        weights = layer.get_weights() # list of numpy arrays
        
        for weight in weights:
        
            print(weight.shape)
            print(weight)

# %% [markdown]
# # Create the Data Handler

# %%
#Selected as per CNN paper
features = ['T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr', 'Ps30', 'phi', 'NRf', 'NRc', 
                     'BPR', 'farB', 'htBleed', 'Nf_dmd', 'PCNfR_dmd', 'W31', 'W32']
selected_indices = np.array([2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 17, 20, 21])
selected_features = list(features[i] for i in selected_indices-1)
data_folder = '../CMAPSSData'

window_size = 30
window_stride = 1
max_rul = 125

dHandler_cmaps = CMAPSDataHandler(data_folder, 1, selected_features, max_rul, window_size, window_stride)
#dHandler_cmaps.load_data(verbose=1, cross_validation_ratio=0.2)

# %% [markdown]
# # Create Tunable Model

# %%
min_max_scaler = MinMaxScaler(feature_range=(-1, 1))
#min_max_scaler = None

# %%
def get_compiled_model(shape, model_type='ann'):
    
    K.clear_session()  #Clear the previous tensorflow graph
    
    #To test the model without randomness
#     seed(0)
#     set_random_seed(0)
    
    #Shared parameters for the models
    optimizer = Adam(lr=0.001,beta_1=0.5)
    
    #optimizer = SGD(lr=0.001, momentum=0.0, decay=0.0, nesterov=False)
    
    lossFunction = "mean_squared_error"
    metrics = ["mse"]
    model = None

    #Create and compile the models

    if model_type=='ann':
        model = RULmodel_SN_5(shape)
        model.compile(optimizer = optimizer, loss = lossFunction, metrics = metrics)
    elif model_type=='lstm':
        model = RULmodel_LSTM(shape)
        model.compile(optimizer = optimizer, loss = lossFunction, metrics = metrics)
    else:
        pass

    return model


# def tf_compiled_model(input_shape, output_shape):
    
#     tf.reset_default_graph()
#     X, y = create_placeholders(input_shape, output_shape)
    
#     y_pred = tf_model(X)
#     cost = tf.losses.mean_squared_error(y, y_pred)
#     reg_cost = tf.losses.get_regularization_loss()
#     total_cost = cost + reg_cost
    
#     optimizer = tf.train.AdamOptimizer(learning_rate=0.001).minimize(total_cost)
    
#     return {'X_placeholder':X, 'y_placeholder':y, 'y_pred':y_pred, 'cost':cost, 'total_cost':total_cost, 'optimizer':optimizer}

# %%
num_features = len(selected_features)

shape = len(selected_features)*window_size
model = get_compiled_model(shape, model_type='ann')
tModel = SequenceTunableModelRegression('ModelRUL_SN_1', model, lib_type='keras', data_handler=dHandler_cmaps)

#shape = (window_size, num_features)
#model = get_compiled_model(shape, model_type='lstm')
#tModel = SequenceTunableModelRegression('ModelRUL_LSTM_1', model, lib_type='keras', data_handler=dHandler_cmaps)
#tModel.data_handler.data_scaler = min_max_scaler
#tModel.data_scaler = min_max_scaler

# %% [markdown]
# # Load Data

# %%
tModel.data_handler.sequence_length = 24
#tModel.data_handler.sequence_length = maxWindowSize[datasetNumber]
tModel.data_handler.sequence_stride = 1
tModel.data_handler.max_rul = 129

# %%
#Load Non sequenced data (unroll sequence into a single feature vector)

tModel.data_handler.data_scaler = None
tModel.data_scaler = min_max_scaler

tModel.load_data(unroll=True, verbose=1, cross_validation_ratio=0)
#tModel.data_handler.print_data()
tModel.print_data()
# Out:
# Loading data for dataset 1 with window_size of 24, stride of 1 and maxRUL of 129. Cros-Validation ratio 0
# Loading data from file and computing dataframes
# Printing shapes
#
# Training data (X, y)
# (18331, 336)
# (18331, 1)
# Testing data (X, y)
# (100, 336)
# (100, 1)
# Printing first 5 elements
#
# Training data (X, y)
# [[-0.59060403 -0.0455243  -0.27982732 ... -0.45454545  0.33333333
#    0.33501825]
#  [-0.36912752  0.0629156  -0.18014129 ... -0.27272727  0.25581395
#    0.50126369]
#  [-0.23489933 -0.13299233 -0.13854003 ... -0.09090909  0.11627907
#    0.46222971]
#  [-0.23489933 -0.39897698 -0.2299843  ... -0.27272727  0.31782946
#    0.55293457]
#  [-0.22147651 -0.39590793 -0.05926217 ... -0.81818182  0.34883721
#    0.09491716]]
# [[129.]
#  [129.]
#  [129.]
#  [129.]
#  [129.]]
# Testing data (X, y)
# [[-0.10738255 -0.49616368 -0.26844584 ... -0.27272727  0.03875969
#    0.29458017]
#  [-0.12751678 -0.18158568  0.02197802 ... -0.63636364  0.03875969
#    0.0322943 ]
#  [ 0.06711409 -0.05473146  0.13814757 ...  0.09090909  0.2248062
#    0.06655434]
#  [-0.1409396   0.15294118  0.00353218 ...  0.09090909 -0.31782946
#    0.02190396]
#  [-0.01342282  0.03273657  0.2032967  ... -0.09090909 -0.05426357
#    0.45324347]]
# [[112.]
#  [ 98.]
#  [ 69.]
#  [ 82.]
#  [ 91.]]

# %%
#Load sequenced data (do not unroll sequence into a single feature vector)

# tModel.data_handler.data_scaler = min_max_scaler
# tModel.data_scaler = None

# tModel.load_data(unroll=False, verbose=1, cross_validation_ratio=0)
# #tModel.data_handler.print_data()
# tModel.print_data()

# %%
#tModel.data_handler.data_scaler = min_max_scaler
#tModel.data_scaler = None

# %% [markdown]
# # Train the model and test some Tunable Model functionalities

# %%
nFeatures = len(selected_features)

lrate = LearningRateScheduler(CMAPSAuxFunctions.step_decay)

shape = len(selected_features)*tModel.data_handler.sequence_length
print(shape)

#modelRULSN = RULmodel_SN_5(shape)
#modelRULSN.compile(optimizer = optimizer, loss = lossFunction, metrics = metrics)

model = get_compiled_model(shape, model_type='ann')
tModel.change_model('ModelRUL_SN_1', model, 'keras')

#model = tf_compiled_model(shape, 1)
#tModel.change_model('ModelRUL_SN_1', model, 'tensorflow')

#tModel.print_data()

#shape = (window_size, num_features)
#model = get_compiled_model(shape, model_type='lstm')
#tModel.change_model('ModelRUL_RNN_1', model, 'keras')

#tModel.data_handler.data_scaler = min_max_scaler
#tModel.data_scaler = min_max_scaler

#print("Printing model weights")
#print_model_weights(tModel.model)

tModel.epochs = 200

tModel.train_model(verbose=1)
# sess = tf.Session()

# tModel.train_model(tf_session=sess, verbose=1)
# Out:
# 336
# Epoch 1/200
# 18331/18331 [==============================] - 1s 30us/step - loss: 7996.3056 - mean_squared_error: 7936.3277
# Epoch 2/200
# 18331/18331 [==============================] - 0s 8us/step - loss: 5216.9066 - mean_squared_error: 5151.3485
# Epoch 3/200
#  - ETA: 0s - loss: 259.3764 - mean_squared_error: 205.2351
# Epoch 200/200
# 18331/18331 [==============================] - 0s 8us/step - loss: 260.0903 - mean_squared_error: 205.9753

# %%
tModel.evaluate_model(['rhs', 'rmse'], round=2)
print("scores")

cScores = tModel.scores
#rmse = math.sqrt(cScores['score_1'])
rmse2 = cScores['rmse']
rhs = cScores['rhs']
time = tModel.train_time

i = range(1,len(tModel.y_test)+1)


for i, rul_prediction, rul_prediction_rounded, true_rul in zip(i, tModel.y_predicted, tModel.y_predicted_rounded, tModel.y_test):
    print('Engine {}, Predicted RUL {}, Rounded RUL {}, Real RUL {}'.format(i, rul_prediction, 
                                                                    rul_prediction_rounded, 
                                                                    true_rul))

print(cScores)
#print("RMSE: {}".format(rmse))
print("RMSE2: {}".format(rmse2))
print("RHS: {}".format(rhs))
print("Time : {} seconds".format(time))
# Out:
# 100/100 [==============================] - 0s 652us/step
# scores
# Engine 1, Predicted RUL [111.45756], Rounded RUL 111.0, Real RUL [112.]
# Engine 2, Predicted RUL [132.84386], Rounded RUL 132.0, Real RUL [98.]
# Engine 3, Predicted RUL [51.104015], Rounded RUL 51.0, Real RUL [69.]
# Engine 4, Predicted RUL [80.72868], Rounded RUL 80.0, Real RUL [82.]
# Engine 5, Predicted RUL [92.93628], Rounded RUL 92.0, Real RUL [91.]
# Engine 6, Predicted RUL [112.3068], Rounded RUL 112.0, Real RUL [93.]
# Engine 7, Predicted RUL [107.17441], Rounded RUL 107.0, Real RUL [91.]
# Engine 8, Predicted RUL [94.48336], Rounded RUL 94.0, Real RUL [95.]
# Engine 9, Predicted RUL [118.68879], Rounded RUL 118.0, Real RUL [111.]
# Engine 10, Predicted RUL [98.63413], Rounded RUL 98.0, Real RUL [96.]
# Engine 11, Predicted RUL [81.9897], Rounded RUL 81.0, Real RUL [97.]
# Engine 12, Predicted RUL [97.678276], Rounded RUL 97.0, Real RUL [124.]
# Engine 13, Predicted RUL [93.78098], Rounded RUL 93.0, Real RUL [95.]
# Engine 14, Predicted RUL [101.41636], Rounded RUL 101.0, Real RUL [107.]
# Engine 15, Predicted RUL [109.64997], Rounded RUL 109.0, Real RUL [83.]
# Engine 16, Predicted RUL [111.160324], Rounded RUL 111.0, Real RUL [84.]
# Engine 17, Predicted RUL [51.655937], Rounded RUL 51.0, Real RUL [50.]
# Engine 18, Predicted RUL [24.990088], Rounded RUL 24.0, Real RUL [28.]
# Engine 19, Predicted RUL [93.16679], Rounded RUL 93.0, Real RUL [87.]
# Engine 20, Predicted RUL [15.142465], Rounded RUL 15.0, Real RUL [16.]
# Engine 21, Predicted RUL [83.009834], Rounded RUL 83.0, Real RUL [57.]
# Engine 22, Predicted RUL [124.79574], Rounded RUL 124.0, Real RUL [111.]
# Engine 23, Predicted RUL [130.43137], Rounded RUL 130.0, Real RUL [113.]
# Engine 24, Predicted RUL [20.34965], Rounded RUL 20.0, Real RUL [20.]
# Engine 25, Predicted RUL [111.30686], Rounded RUL 111.0, Real RUL [145.]
# Engine 26, Predicted RUL [117.00076], Rounded RUL 117.0, Real RUL [119.]
# Engine 27, Predicted RUL [106.014656], Rounded RUL 106.0, Real RUL [66.]
# Engine 28, Predicted RUL [112.56221], Rounded RUL 112.0, Real RUL [97.]
# Engine 29, Predicted RUL [98.00972], Rounded RUL 98.0, Real RUL [90.]
# Engine 30, Predicted RUL [108.196556], Rounded RUL 108.0, Real RUL [115.]
# Engine 31, Predicted RUL [12.047205], Rounded RUL 12.0, Real RUL [8.]
# Engine 32, Predicted RUL [54.50251], Rounded RUL 54.0, Real RUL [48.]
# Engine 33, Predicted RUL [108.63851], Rounded RUL 108.0, Real RUL [106.]
# Engine 34, Predicted RUL [4.014924], Rounded RUL 4.0, Real RUL [7.]
# Engine 35, Predicted RUL [12.904047], Rounded RUL 12.0, Real RUL [11.]
# Engine 36, Predicted RUL [28.661509], Rounded RUL 28.0, Real RUL [19.]
# Engine 37, Predicted RUL [18.40346], Rounded RUL 18.0, Real RUL [21.]
# Engine 38, Predicted RUL [53.54259], Rounded RUL 53.0, Real RUL [50.]
# Engine 39, Predicted RUL [128.62529], Rounded RUL 128.0, Real RUL [142.]
# Engine 40, Predicted RUL [26.467705], Rounded RUL 26.0, Real RUL [28.]
# Engine 41, Predicted RUL [25.829123], Rounded RUL 25.0, Real RUL [18.]
# Engine 42, Predicted RUL [6.725415], Rounded RUL 6.0, Real RUL [10.]
# Engine 43, Predicted RUL [66.90633], Rounded RUL 66.0, Real RUL [59.]
# Engine 44, Predicted RUL [116.091446], Rounded RUL 116.0, Real RUL [109.]
# Engine 45, Predicted RUL [87.9593], Rounded RUL 87.0, Real RUL [114.]
# Engine 46, Predicted RUL [50.27049], Rounded RUL 50.0, Real RUL [47.]
# Engine 47, Predicted RUL [114.55079], Rounded RUL 114.0, Real RUL [135.]
# Engine 48, Predicted RUL [99.37626], Rounded RUL 99.0, Real RUL [92.]
# Engine 49, Predicted RUL [16.109756], Rounded RUL 16.0, Real RUL [21.]
# Engine 50, Predicted RUL [76.51449], Rounded RUL 76.0, Real RUL [79.]
# Engine 51, Predicted RUL [123.80896], Rounded RUL 123.0, Real RUL [114.]
# Engine 52, Predicted RUL [27.1297], Rounded RUL 27.0, Real RUL [29.]
# Engine 53, Predicted RUL [31.355625], Rounded RUL 31.0, Real RUL [26.]
# Engine 54, Predicted RUL [119.82341], Rounded RUL 119.0, Real RUL [97.]
# Engine 55, Predicted RUL [113.52505], Rounded RUL 113.0, Real RUL [137.]
# Engine 56, Predicted RUL [19.235357], Rounded RUL 19.0, Real RUL [15.]
# Engine 57, Predicted RUL [101.73253], Rounded RUL 101.0, Real RUL [103.]
# Engine 58, Predicted RUL [39.87379], Rounded RUL 39.0, Real RUL [37.]
# Engine 59, Predicted RUL [106.23094], Rounded RUL 106.0, Real RUL [114.]
# Engine 60, Predicted RUL [122.959404], Rounded RUL 122.0, Real RUL [100.]
# Engine 61, Predicted RUL [17.92779], Rounded RUL 17.0, Real RUL [21.]
# Engine 62, Predicted RUL [47.28824], Rounded RUL 47.0, Real RUL [54.]
# Engine 63, Predicted RUL [82.96446], Rounded RUL 82.0, Real RUL [72.]
# Engine 64, Predicted RUL [24.87394], Rounded RUL 24.0, Real RUL [28.]
# Engine 65, Predicted RUL [125.70968], Rounded RUL 125.0, Real RUL [128.]
# Engine 66, Predicted RUL [18.74191], Rounded RUL 18.0, Real RUL [14.]
# Engine 67, Predicted RUL [114.531105], Rounded RUL 114.0, Real RUL [77.]
# Engine 68, Predicted RUL [8.399998], Rounded RUL 8.0, Real RUL [8.]
# Engine 69, Predicted RUL [112.357956], Rounded RUL 112.0, Real RUL [121.]
# Engine 70, Predicted RUL [98.99797], Rounded RUL 98.0, Real RUL [94.]
# Engine 71, Predicted RUL [108.871574], Rounded RUL 108.0, Real RUL [118.]
# Engine 72, Predicted RUL [60.169594], Rounded RUL 60.0, Real RUL [50.]
# Engine 73, Predicted RUL [116.51195], Rounded RUL 116.0, Real RUL [131.]
# Engine 74, Predicted RUL [107.722626], Rounded RUL 107.0, Real RUL [126.]
# Engine 75, Predicted RUL [106.969894], Rounded RUL 106.0, Real RUL [113.]
# Engine 76, Predicted RUL [6.1843805], Rounded RUL 6.0, Real RUL [10.]
# Engine 77, Predicted RUL [29.7654], Rounded RUL 29.0, Real RUL [34.]
# Engine 78, Predicted RUL [133.16872], Rounded RUL 133.0, Real RUL [107.]
# Engine 79, Predicted RUL [93.573814], Rounded RUL 93.0, Real RUL [63.]
# Engine 80, Predicted RUL [96.42841], Rounded RUL 96.0, Real RUL [90.]
# Engine 81, Predicted RUL [9.66682], Rounded RUL 9.0, Real RUL [8.]
# Engine 82, Predicted RUL [7.726347], Rounded RUL 7.0, Real RUL [9.]
# Engine 83, Predicted RUL [121.845535], Rounded RUL 121.0, Real RUL [137.]
# Engine 84, Predicted RUL [72.413826], Rounded RUL 72.0, Real RUL [58.]
# Engine 85, Predicted RUL [130.60461], Rounded RUL 130.0, Real RUL [118.]
# Engine 86, Predicted RUL [107.81906], Rounded RUL 107.0, Real RUL [89.]
# Engine 87, Predicted RUL [117.331474], Rounded RUL 117.0, Real RUL [116.]
# Engine 88, Predicted RUL [119.946594], Rounded RUL 119.0, Real RUL [115.]
# Engine 89, Predicted RUL [114.95212], Rounded RUL 114.0, Real RUL [136.]
# Engine 90, Predicted RUL [27.907667], Rounded RUL 27.0, Real RUL [28.]
# Engine 91, Predicted RUL [24.82324], Rounded RUL 24.0, Real RUL [38.]
# Engine 92, Predicted RUL [25.248585], Rounded RUL 25.0, Real RUL [20.]
# Engine 93, Predicted RUL [53.75779], Rounded RUL 53.0, Real RUL [85.]
# Engine 94, Predicted RUL [62.54671], Rounded RUL 62.0, Real RUL [55.]
# Engine 95, Predicted RUL [108.28203], Rounded RUL 108.0, Real RUL [128.]
# Engine 96, Predicted RUL [111.33826], Rounded RUL 111.0, Real RUL [137.]
# Engine 97, Predicted RUL [88.94352], Rounded RUL 88.0, Real RUL [82.]
# Engine 98, Predicted RUL [88.912605], Rounded RUL 88.0, Real RUL [59.]
# Engine 99, Predicted RUL [118.54669], Rounded RUL 118.0, Real RUL [117.]
# Engine 100, Predicted RUL [21.992409], Rounded RUL 21.0, Real RUL [20.]
# {'loss': 267.62494506835935, 'score_1': 213.538662109375, 'rhs': 3.684772394974301, 'rmse': 14.574292435655323}
# RMSE2: 14.574292435655323
# RHS: 3.684772394974301
# Time : 50.198222000000015 seconds
